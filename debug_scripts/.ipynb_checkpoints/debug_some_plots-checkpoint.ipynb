# %%
# MODULE IMPORTS ----

# warning settings
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# Data management
import pandas as pd
import numpy as np
import pickle

# Plotting
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns

# Stats functionality
from statsmodels.distributions.empirical_distribution import ECDF

# HDDM
import hddm

# %%
out = hddm.simulators.simulator_h_c(model = 'ddm',
                              theta = [0., 1., 0.5, 0.5],
                              n_trials_per_subject = 100,
                              n_subjects = 5,
                              regression_covariates = None,
                              depends_on = {})

# %%
dataset = out[0]
dataset['cov1'] = np.random.choice(2, size = 500) # - 0.5
dataset['cov2'] = np.random.choice(2, size = 500) # - 0.5
dataset['cov3'] = np.random.choice(2, size = 500) # - 0.5

# %%
# v_reg = {'model' : "v ~ 1 + C(Valence) + C(MFCTType)", 'link_func' : lambda x: x}
# t_reg = {'model' : "t ~ 1 + C(Action)", 'link_func' : lambda x: x}
# a_reg = {'model' : 'a ~ 1 + C(Valence) * C(Action)', 'link_func' : lambda x: x}
# reg_descr = [t_reg, a_reg, v_reg]
# m = hddm.HDDMRegressor(data1, reg_descr, p_outlier = .05)

# %%
v_reg = {'model' : "v ~ 1 + C(cov1) + C(cov2)", 'link_func' : lambda x: x}
t_reg = {'model' : "t ~ 1 + C(cov3)", 'link_func' : lambda x: x}
a_reg = {'model' : 'a ~ 1 + C(cov1) * C(cov3)', 'link_func' : lambda x: x}
reg_descr = [t_reg, a_reg, v_reg]
m = hddm.HDDMRegressor(dataset, reg_descr, p_outlier = .05, include = ['z'])
# Out:
# No model attribute --> setting up standard HDDM
# Set model to ddm

# %%
m.sample(500, burn = 200, db = 'pickle', dbname = 'traces.db')
# Out:
#  [-----------------100%-----------------] 501 of 500 complete in 488.9 sec

# %%
hddm.plotting.plot_caterpillar(m)
# Out:
# tracename:
# v_Intercept
# tracename:
# v_Intercept_subj.0
# tracename:
# v_Intercept_subj.1
# tracename:
# v_Intercept_subj.2
# tracename:
# v_Intercept_subj.3
# tracename:
# v_Intercept_subj.4
# tracename:
# v_C(cov1)[T.0.5]
# tracename:
# v_C(cov2)[T.0.5]
# tracename:
# a_Intercept
# tracename:
# a_Intercept_rate
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-fa8a7dc38096> in <module>
# ----> 1 hddm.plotting.plot_caterpillar(m)
#
# ~/OneDrive/project_hddm_extension/hddm/hddm/plotting.py in plot_caterpillar(hddm_model, ground_truth_parameter_dict, drop_sd, keep_key, figsize, columns, save, path, format, y_tick_size, x_tick_size)
#    1976                             tmp_sorted = sorted(transformed_trace)
#    1977                         else:
# -> 1978                             ecdfs[k] = ECDF(traces_tmp[k].values)
#    1979                             tmp_sorted = sorted(traces_tmp[k].values)
#    1980                     else:
#
# ~/opt/miniconda3/envs/hddmnn_tutorial/lib/python3.7/site-packages/statsmodels/distributions/empirical_distribution.py in __init__(self, x, side)
#     134     def __init__(self, x, side='right'):
#     135         x = np.array(x, copy=True)
# --> 136         x.sort()
#     137         nobs = len(x)
#     138         y = np.linspace(1./nobs,1,nobs)
#
# TypeError: '<' not supported between instances of 'NoneType' and 'NoneType'

# %%
m.get_traces()['a_Intercept_rate']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/miniconda3/envs/hddmnn_tutorial/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/opt/miniconda3/envs/hddmnn_tutorial/lib/python3.7/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/miniconda3/envs/hddmnn_tutorial/lib/python3.7/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'a_Intercept_rate'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-41e423c8d853> in <module>
# ----> 1 m.get_traces()['a_Intercept_rate']
#
# ~/opt/miniconda3/envs/hddmnn_tutorial/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# ~/opt/miniconda3/envs/hddmnn_tutorial/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'a_Intercept_rate'

# %%
plt.show()

# %%
m.save('test.pickle')

# %%
m = hddm.load('test.pickle')

# %%
m.nodes_db.index
# Out:
# Index(['z_trans', 'z', 'z_std', 'z_tau', 'z_subj_trans.0', 'z_subj_trans.1',
#        'z_subj_trans.2', 'z_subj_trans.3', 'z_subj_trans.4', 'z_subj.0',
#        'z_subj.1', 'z_subj.2', 'z_subj.3', 'z_subj.4', 't_Intercept',
#        't_Intercept_std', 't_Intercept_rate', 't_Intercept_shape',
#        't_Intercept_subj.0', 't_Intercept_subj.1', 't_Intercept_subj.2',
#        't_Intercept_subj.3', 't_Intercept_subj.4', 't_C(cov3)[T.1]', 't_reg.0',
#        't_reg.1', 't_reg.2', 't_reg.3', 't_reg.4', 'a_Intercept',
#        'a_Intercept_std', 'a_Intercept_rate', 'a_Intercept_shape',
#        'a_Intercept_subj.0', 'a_Intercept_subj.1', 'a_Intercept_subj.2',
#        'a_Intercept_subj.3', 'a_Intercept_subj.4', 'a_C(cov1)[T.1]',
#        'a_C(cov3)[T.1]', 'a_C(cov1)[T.1]:C(cov3)[T.1]', 'a_reg.0', 'a_reg.1',
#        'a_reg.2', 'a_reg.3', 'a_reg.4', 'v_Intercept', 'v_Intercept_std',
#        'v_Intercept_tau', 'v_Intercept_subj.0', 'v_Intercept_subj.1',
#        'v_Intercept_subj.2', 'v_Intercept_subj.3', 'v_Intercept_subj.4',
#        'v_C(cov1)[T.1]', 'v_C(cov2)[T.1]', 'v_reg.0', 'v_reg.1', 'v_reg.2',
#        'v_reg.3', 'v_reg.4', 'wfpt.0', 'wfpt.1', 'wfpt.2', 'wfpt.3', 'wfpt.4'],
#       dtype='object')

# %%
m.nodes_db.keys()
# Out:
# Index(['knode_name', 'stochastic', 'observed', 'subj', 'node', 'tag',
#        'depends', 'hidden', 'rt', 'response', 'subj_idx', 'v', 'a', 'z', 't',
#        'cov1', 'cov2', 'cov3', 'mean', 'std', '2.5q', '25q', '50q', '75q',
#        '97.5q', 'mc err'],
#       dtype='object')

# %%
m.nodes_db[m.nodes_db['stochastic'] == True]
# Out:
#                                                       knode_name stochastic  \
# t_Intercept                                          t_Intercept       True
# t_Intercept_std                                  t_Intercept_std       True
# t_Intercept_subj.0                              t_Intercept_subj       True
# t_Intercept_subj.1                              t_Intercept_subj       True
# t_Intercept_subj.2                              t_Intercept_subj       True
# t_Intercept_subj.3                              t_Intercept_subj       True
# t_Intercept_subj.4                              t_Intercept_subj       True
# t_C(cov3)[T.0.5]                                t_C(cov3)[T.0.5]       True
# a_Intercept                                          a_Intercept       True
# a_Intercept_std                                  a_Intercept_std       True
# a_Intercept_subj.0                              a_Intercept_subj       True
# a_Intercept_subj.1                              a_Intercept_subj       True
# a_Intercept_subj.2                              a_Intercept_subj       True
# a_Intercept_subj.3                              a_Intercept_subj       True
# a_Intercept_subj.4                              a_Intercept_subj       True
# a_C(cov1)[T.0.5]                                a_C(cov1)[T.0.5]       True
# a_C(cov3)[T.0.5]                                a_C(cov3)[T.0.5]       True
# a_C(cov1)[T.0.5]:C(cov3)[T.0.5]  a_C(cov1)[T.0.5]:C(cov3)[T.0.5]       True
# v_Intercept                                          v_Intercept       True
# v_Intercept_std                                  v_Intercept_std       True
# v_Intercept_subj.0                              v_Intercept_subj       True
# v_Intercept_subj.1                              v_Intercept_subj       True
# v_Intercept_subj.2                              v_Intercept_subj       True
# v_Intercept_subj.3                              v_Intercept_subj       True
# v_Intercept_subj.4                              v_Intercept_subj       True
# v_C(cov1)[T.0.5]                                v_C(cov1)[T.0.5]       True
# v_C(cov2)[T.0.5]                                v_C(cov2)[T.0.5]       True
#
#                                 observed   subj  \
# t_Intercept                        False  False
# t_Intercept_std                    False  False
# t_Intercept_subj.0                 False   True
# t_Intercept_subj.1                 False   True
# t_Intercept_subj.2                 False   True
# t_Intercept_subj.3                 False   True
# t_Intercept_subj.4                 False   True
# t_C(cov3)[T.0.5]                   False  False
# a_Intercept                        False  False
# a_Intercept_std                    False  False
# a_Intercept_subj.0                 False   True
# a_Intercept_subj.1                 False   True
# a_Intercept_subj.2                 False   True
# a_Intercept_subj.3                 False   True
# a_Intercept_subj.4                 False   True
# a_C(cov1)[T.0.5]                   False  False
# a_C(cov3)[T.0.5]                   False  False
# a_C(cov1)[T.0.5]:C(cov3)[T.0.5]    False  False
# v_Intercept                        False  False
# v_Intercept_std                    False  False
# v_Intercept_subj.0                 False   True
# v_Intercept_subj.1                 False   True
# v_Intercept_subj.2                 False   True
# v_Intercept_subj.3                 False   True
# v_Intercept_subj.4                 False   True
# v_C(cov1)[T.0.5]                   False  False
# v_C(cov2)[T.0.5]                   False  False
#
#                                                             node tag  \
# t_Intercept                                          t_Intercept  ()
# t_Intercept_std                                  t_Intercept_std  ()
# t_Intercept_subj.0                            t_Intercept_subj.0  ()
# t_Intercept_subj.1                            t_Intercept_subj.1  ()
# t_Intercept_subj.2                            t_Intercept_subj.2  ()
# t_Intercept_subj.3                            t_Intercept_subj.3  ()
# t_Intercept_subj.4                            t_Intercept_subj.4  ()
# t_C(cov3)[T.0.5]                                t_C(cov3)[T.0.5]  ()
# a_Intercept                                          a_Intercept  ()
# a_Intercept_std                                  a_Intercept_std  ()
# a_Intercept_subj.0                            a_Intercept_subj.0  ()
# a_Intercept_subj.1                            a_Intercept_subj.1  ()
# a_Intercept_subj.2                            a_Intercept_subj.2  ()
# a_Intercept_subj.3                            a_Intercept_subj.3  ()
# a_Intercept_subj.4                            a_Intercept_subj.4  ()
# a_C(cov1)[T.0.5]                                a_C(cov1)[T.0.5]  ()
# a_C(cov3)[T.0.5]                                a_C(cov3)[T.0.5]  ()
# a_C(cov1)[T.0.5]:C(cov3)[T.0.5]  a_C(cov1)[T.0.5]:C(cov3)[T.0.5]  ()
# v_Intercept                                          v_Intercept  ()
# v_Intercept_std                                  v_Intercept_std  ()
# v_Intercept_subj.0                            v_Intercept_subj.0  ()
# v_Intercept_subj.1                            v_Intercept_subj.1  ()
# v_Intercept_subj.2                            v_Intercept_subj.2  ()
# v_Intercept_subj.3                            v_Intercept_subj.3  ()
# v_Intercept_subj.4                            v_Intercept_subj.4  ()
# v_C(cov1)[T.0.5]                                v_C(cov1)[T.0.5]  ()
# v_C(cov2)[T.0.5]                                v_C(cov2)[T.0.5]  ()
#
#                                     depends hidden   rt response  ... cov2  \
# t_Intercept                              []  False  NaN      NaN  ...  NaN
# t_Intercept_std                          []  False  NaN      NaN  ...  NaN
# t_Intercept_subj.0               [subj_idx]  False  NaN      NaN  ...  NaN
# t_Intercept_subj.1               [subj_idx]  False  NaN      NaN  ...  NaN
# t_Intercept_subj.2               [subj_idx]  False  NaN      NaN  ...  NaN
# t_Intercept_subj.3               [subj_idx]  False  NaN      NaN  ...  NaN
# t_Intercept_subj.4               [subj_idx]  False  NaN      NaN  ...  NaN
# t_C(cov3)[T.0.5]                         []  False  NaN      NaN  ...  NaN
# a_Intercept                              []  False  NaN      NaN  ...  NaN
# a_Intercept_std                          []  False  NaN      NaN  ...  NaN
# a_Intercept_subj.0               [subj_idx]  False  NaN      NaN  ...  NaN
# a_Intercept_subj.1               [subj_idx]  False  NaN      NaN  ...  NaN
# a_Intercept_subj.2               [subj_idx]  False  NaN      NaN  ...  NaN
# a_Intercept_subj.3               [subj_idx]  False  NaN      NaN  ...  NaN
# a_Intercept_subj.4               [subj_idx]  False  NaN      NaN  ...  NaN
# a_C(cov1)[T.0.5]                         []  False  NaN      NaN  ...  NaN
# a_C(cov3)[T.0.5]                         []  False  NaN      NaN  ...  NaN
# a_C(cov1)[T.0.5]:C(cov3)[T.0.5]          []  False  NaN      NaN  ...  NaN
# v_Intercept                              []  False  NaN      NaN  ...  NaN
# v_Intercept_std                          []  False  NaN      NaN  ...  NaN
# v_Intercept_subj.0               [subj_idx]  False  NaN      NaN  ...  NaN
# v_Intercept_subj.1               [subj_idx]  False  NaN      NaN  ...  NaN
# v_Intercept_subj.2               [subj_idx]  False  NaN      NaN  ...  NaN
# v_Intercept_subj.3               [subj_idx]  False  NaN      NaN  ...  NaN
# v_Intercept_subj.4               [subj_idx]  False  NaN      NaN  ...  NaN
# v_C(cov1)[T.0.5]                         []  False  NaN      NaN  ...  NaN
# v_C(cov2)[T.0.5]                         []  False  NaN      NaN  ...  NaN
#
#                                 cov3      mean       std      2.5q       25q  \
# t_Intercept                      NaN  0.346427   0.02958  0.295603  0.326513
# t_Intercept_std                  NaN  0.047146   0.02697  0.009328  0.030081
# t_Intercept_subj.0               NaN  0.354298  0.036882  0.273646  0.332089
# t_Intercept_subj.1               NaN  0.367983  0.029013  0.305799  0.348442
# t_Intercept_subj.2               NaN  0.306138  0.020762  0.262079   0.29367
# t_Intercept_subj.3               NaN   0.34769  0.036325  0.272641  0.325831
# t_Intercept_subj.4               NaN  0.341988  0.024829  0.286689  0.328434
# t_C(cov3)[T.0.5]                 NaN -0.034994  0.025396 -0.084265 -0.052782
# a_Intercept                      NaN  2.152763  0.273539  1.656572  1.986874
# a_Intercept_std                  NaN  0.559804  0.282002  0.220679  0.360426
# a_Intercept_subj.0               NaN  2.549592  0.129505  2.279687  2.468917
# a_Intercept_subj.1               NaN  1.875005  0.115072  1.676241  1.795444
# a_Intercept_subj.2               NaN  1.734134  0.107064  1.530384  1.659279
# a_Intercept_subj.3               NaN   2.52128  0.129028  2.283466  2.425531
# a_Intercept_subj.4               NaN  2.055878  0.114516  1.820084  1.983554
# a_C(cov1)[T.0.5]                 NaN -0.030927  0.101053 -0.221825 -0.092116
# a_C(cov3)[T.0.5]                 NaN -0.173899  0.106946 -0.376949 -0.249873
# a_C(cov1)[T.0.5]:C(cov3)[T.0.5]  NaN   0.15936  0.140478 -0.102283   0.06385
# v_Intercept                      NaN  0.227304  0.137217 -0.031407  0.151304
# v_Intercept_std                  NaN  0.184345  0.127992  0.031535  0.105784
# v_Intercept_subj.0               NaN   0.09305  0.117576 -0.122049  0.018173
# v_Intercept_subj.1               NaN  0.237191  0.114326 -0.001714  0.167739
# v_Intercept_subj.2               NaN  0.246785  0.128492   -0.0041  0.160167
# v_Intercept_subj.3               NaN  0.334648  0.106044  0.127179    0.2586
# v_Intercept_subj.4               NaN  0.226103  0.110665  0.008951  0.144626
# v_C(cov1)[T.0.5]                 NaN  0.059024   0.09515 -0.117304   -0.0001
# v_C(cov2)[T.0.5]                 NaN -0.032231  0.093351 -0.221386 -0.091652
#
#                                       50q       75q     97.5q    mc err
# t_Intercept                      0.346321  0.364376  0.412459  0.002339
# t_Intercept_std                  0.043483  0.057226  0.116531  0.002327
# t_Intercept_subj.0               0.356898  0.380768  0.417323  0.002793
# t_Intercept_subj.1               0.370768  0.389181  0.420283  0.002407
# t_Intercept_subj.2               0.307712  0.322122  0.340437  0.001632
# t_Intercept_subj.3               0.350645  0.372491  0.411727  0.002731
# t_Intercept_subj.4               0.343593  0.357118  0.387376  0.001869
# t_C(cov3)[T.0.5]                -0.035593 -0.014524  0.012063   0.00222
# a_Intercept                      2.120473  2.309039  2.778968  0.019332
# a_Intercept_std                  0.495131   0.69985  1.226626  0.021752
# a_Intercept_subj.0               2.544025  2.631875  2.799761  0.009297
# a_Intercept_subj.1                1.87237  1.950364  2.128127  0.009469
# a_Intercept_subj.2               1.730558  1.805049   1.93728  0.009058
# a_Intercept_subj.3                2.52498  2.604048  2.784385  0.009953
# a_Intercept_subj.4               2.057649  2.129434  2.272989  0.008762
# a_C(cov1)[T.0.5]                -0.033449  0.027567   0.19895  0.008778
# a_C(cov3)[T.0.5]                -0.167498 -0.096403   0.02092  0.009552
# a_C(cov1)[T.0.5]:C(cov3)[T.0.5]  0.150503  0.249317  0.448416  0.011929
# v_Intercept                      0.227561  0.315462  0.502454  0.011105
# v_Intercept_std                  0.151337  0.235538  0.492543  0.011457
# v_Intercept_subj.0               0.083742  0.166112   0.35701  0.010095
# v_Intercept_subj.1               0.236639    0.3069   0.46354   0.00853
# v_Intercept_subj.2               0.258979  0.350346  0.463386  0.010259
# v_Intercept_subj.3               0.335743  0.402454  0.568043  0.008353
# v_Intercept_subj.4                0.22423  0.293869  0.454871  0.008742
# v_C(cov1)[T.0.5]                 0.060947  0.122703  0.240331  0.007376
# v_C(cov2)[T.0.5]                -0.026027  0.025542  0.157937   0.00735
#
# [27 rows x 26 columns]

# %%
out1, out2 = hddm.plotting.plot_caterpillar(m)

# %%
hddm.plotting.plot_caterpillar(m)
# Out:
# tracename:
# v_Intercept
# tracename:
# v_Intercept_subj.0
# tracename:
# v_Intercept_subj.1
# tracename:
# v_Intercept_subj.2
# tracename:
# v_Intercept_subj.3
# tracename:
# v_Intercept_subj.4
# tracename:
# v_C(cov1)[T.1]
# tracename:
# v_C(cov2)[T.1]
# tracename:
# a_Intercept
# tracename:
# a_Intercept_subj.0
# tracename:
# a_Intercept_subj.1
# tracename:
# a_Intercept_subj.2
# tracename:
# a_Intercept_subj.3
# tracename:
# a_Intercept_subj.4
# tracename:
# a_C(cov1)[T.1]
# tracename:
# a_C(cov3)[T.1]
# tracename:
# a_C(cov1)[T.1]:C(cov3)[T.1]
# tracename:
# z
# tracename:
# z_subj.0
# tracename:
# z_subj.1
# tracename:
# z_subj.2
# tracename:
# z_subj.3
# tracename:
# z_subj.4
# tracename:
# t_Intercept
# tracename:
# t_Intercept_subj.0
# tracename:
# t_Intercept_subj.1
# tracename:
# t_Intercept_subj.2
# tracename:
# t_Intercept_subj.3
# tracename:
# t_Intercept_subj.4
# tracename:
# t_C(cov3)[T.1]

# %%
out2
# Out:
# {'v':      v_Intercept  v_Intercept_std  v_Intercept_subj.0  v_Intercept_subj.1  \
#  0       0.375146         0.015543            0.356259            0.355132
#  1       0.362162         0.014138            0.366010            0.370243
#  2       0.360935         0.019168            0.355408            0.341675
#  3       0.357747         0.018284            0.345427            0.334159
#  4       0.365916         0.010477            0.357010            0.366548
#  ..           ...              ...                 ...                 ...
#  295     0.175077         0.227308           -0.096640            0.217440
#  296     0.162807         0.255281            0.038880            0.208623
#  297     0.089412         0.183785           -0.028577            0.210419
#  298     0.151304         0.199954            0.030974            0.130218
#  299     0.274149         0.250675            0.035163            0.129442
#
#       v_Intercept_subj.2  v_Intercept_subj.3  v_Intercept_subj.4  \
#  0              0.367756            0.392055            0.377902
#  1              0.368035            0.342714            0.362913
#  2              0.340202            0.364403            0.361888
#  3              0.377574            0.353784            0.366100
#  4              0.373106            0.372157            0.373536
#  ..                  ...                 ...                 ...
#  295            0.249635            0.158713            0.114486
#  296            0.110480            0.221328            0.166047
#  297           -0.006306            0.251294            0.191537
#  298            0.185476            0.222190            0.273725
#  299            0.243876            0.213850            0.373703
#
#       v_C(cov1)[T.0.5]  v_C(cov2)[T.0.5]
#  0           -0.067535         -0.248103
#  1           -0.084258         -0.082736
#  2            0.021954         -0.135094
#  3           -0.126366         -0.073156
#  4           -0.145082         -0.090998
#  ..                ...               ...
#  295          0.271634         -0.014922
#  296          0.149029         -0.012818
#  297          0.134053          0.038171
#  298          0.115122         -0.004063
#  299          0.095747         -0.001832
#
#  [300 rows x 9 columns],
#  'a':      a_Intercept  a_Intercept_std a_Intercept_rate a_Intercept_shape  \
#  0       2.026749         0.364865             None              None
#  1       2.015989         0.516071             None              None
#  2       2.216072         0.360426             None              None
#  3       2.186608         0.312477             None              None
#  4       2.171626         0.415469             None              None
#  ..           ...              ...              ...               ...
#  295     2.013914         0.531256             None              None
#  296     2.092021         0.445840             None              None
#  297     2.198774         0.477698             None              None
#  298     1.977215         0.347338             None              None
#  299     1.918938         0.317200             None              None
#
#       a_Intercept_subj.0  a_Intercept_subj.1  a_Intercept_subj.2  \
#  0              2.243261            1.772741            1.690884
#  1              2.252507            1.818262            1.626653
#  2              2.524122            1.802430            1.775535
#  3              2.472155            1.990630            1.711816
#  4              2.452917            1.981346            1.809848
#  ..                  ...                 ...                 ...
#  295            2.452398            1.914544            1.659262
#  296            2.402892            1.973199            1.558977
#  297            2.518391            1.834808            1.552435
#  298            2.580164            1.837121            1.530384
#  299            2.601491            1.823580            1.812556
#
#       a_Intercept_subj.3  a_Intercept_subj.4  a_C(cov1)[T.0.5]  \
#  0              2.349775            2.148944         -0.034634
#  1              2.531044            1.983554         -0.078582
#  2              2.507666            2.019352         -0.123027
#  3              2.530318            2.057649         -0.034196
#  4              2.639883            2.137274         -0.129937
#  ..                  ...                 ...               ...
#  295            2.264517            2.075815          0.033771
#  296            2.459330            2.066860          0.017478
#  297            2.510063            2.109285          0.012402
#  298            2.286081            2.000236          0.063422
#  299            2.423516            1.945435          0.201701
#
#       a_C(cov3)[T.0.5]  a_C(cov1)[T.0.5]:C(cov3)[T.0.5]
#  0            0.103013                         0.137902
#  1            0.067427                         0.139815
#  2            0.017158                         0.135646
#  3           -0.168150                         0.130297
#  4           -0.124671                         0.128290
#  ..                ...                              ...
#  295         -0.098149                         0.166506
#  296         -0.129559                         0.178032
#  297         -0.177758                         0.189207
#  298         -0.180665                        -0.015547
#  299         -0.093933                         0.043971
#
#  [300 rows x 12 columns],
#  't':      t_Intercept  t_Intercept_std t_Intercept_rate t_Intercept_shape  \
#  0       0.365460         0.058770             None              None
#  1       0.362362         0.040159             None              None
#  2       0.341140         0.041894             None              None
#  3       0.359117         0.054854             None              None
#  4       0.294783         0.046405             None              None
#  ..           ...              ...              ...               ...
#  295     0.351420         0.016100             None              None
#  296     0.347133         0.012919             None              None
#  297     0.341662         0.023207             None              None
#  298     0.326649         0.016386             None              None
#  299     0.344322         0.014818             None              None
#
#       t_Intercept_subj.0  t_Intercept_subj.1  t_Intercept_subj.2  \
#  0              0.427607            0.378280            0.303316
#  1              0.405063            0.367744            0.293517
#  2              0.407149            0.381541            0.292611
#  3              0.363023            0.375054            0.318734
#  4              0.384068            0.344933            0.310982
#  ..                  ...                 ...                 ...
#  295            0.375320            0.354290            0.328424
#  296            0.374102            0.336052            0.335928
#  297            0.328898            0.352356            0.316113
#  298            0.341690            0.349274            0.313826
#  299            0.319092            0.334957            0.318599
#
#       t_Intercept_subj.3  t_Intercept_subj.4  t_C(cov3)[T.0.5]
#  0              0.392651            0.309383         -0.051809
#  1              0.337172            0.346824         -0.049096
#  2              0.343572            0.348749         -0.070654
#  3              0.375802            0.354555         -0.040691
#  4              0.304207            0.359625         -0.072695
#  ..                  ...                 ...               ...
#  295            0.361478            0.343348         -0.056434
#  296            0.370369            0.347238         -0.056930
#  297            0.334833            0.342459         -0.035568
#  298            0.341446            0.348574         -0.037356
#  299            0.350077            0.336821         -0.033666
#
#  [300 rows x 10 columns]}
