# %%
# %load_ext autoreload

# %%
# !pwd
# Out:
# /Users/afengler/OneDrive/git_repos/hddmnn_tutorial

# %%
# %reload_ext autoreload

# MODULE IMPORTS ----
# warning settings
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# Data management
import pandas as pd
import numpy as np
import pickle

# Plotting
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns

# Stats functionality
from statsmodels.distributions.empirical_distribution import ECDF

# HDDM
import hddm

import pymc as pm
import os

# %%
def _post_pred_generate(bottom_node, samples=500, data=None, append_data=False, add_model_parameters=False):
    """Generate posterior predictive data from a single observed node."""
    datasets = []

    ##############################
    # Sample and generate stats
    for sample in range(samples):
        _parents_to_random_posterior_sample(bottom_node)
        # Generate data from bottom node
        sampled_data = bottom_node.random(add_model_parameters = add_model_parameters)
        if append_data and data is not None:
            sampled_data = sampled_data.join(data.reset_index(), lsuffix='_sampled')
        datasets.append(sampled_data)
    return datasets

# %%
def _parents_to_random_posterior_sample(bottom_node, pos=None):
    """Walks through parents and sets them to pos sample."""
    for i, parent in enumerate(bottom_node.extended_parents):
        if not isinstance(parent, pm.Node): # Skip non-stochastic nodes
            continue

        if pos is None:
            # Set to random posterior position
            pos = np.random.randint(0, len(parent.trace()))

        assert len(parent.trace()) >= pos, "pos larger than posterior sample size"
        parent.value = parent.trace()[pos]

# %%
def pretty_tag(tag):
    return tag[0] if len(tag) == 1 else ', '.join(str(tag))

# %% [markdown]
# # Testing Fun

# %%
# Metadata
nmcmc = 200
model = 'angle'
n_samples_by_subject = 500

# %%
data, full_parameter_dict = hddm.simulators.hddm_dataset_generators.simulator_h_c(n_subjects = 3,
                                                                                  n_samples_by_subject = n_samples_by_subject,
                                                                                  model = model,
                                                                                  p_outlier = 0.00,
                                                                                  conditions = None, 
                                                                                  depends_on = None, 
                                                                                  regression_models = ['t ~ 1 + covariate_name', 'v ~ 1 + covariate_name'], 
                                                                                  regression_covariates = {'covariate_name': {'type': 'continuous', 'range': (0, 1)},
                                                                                                          'covariate_name_2': {'type': 'continuous', 'range': (0, 1)}},
                                                                                  group_only_regressors = False,
                                                                                  group_only = None,
                                                                                  fixed_at_default = None)

# %%
# Set up the regressor a regressor:
reg_model_v = {'model': 'v ~ 1 + covariate_name', 'link_func': lambda x: x}
reg_model_t = {'model': 't ~ 1 + covariate_name', 'link_func': lambda x: x}
reg_descr = [reg_model_t, reg_model_v]

# %%
# Make HDDM model
hddmnn_reg = hddm.HDDMnnRegressor(data,
                                  reg_descr, 
                                  include = hddm.simulators.model_config[model]['hddm_include'],
                                  model = model,
                                  informative = False,
                                  p_outlier = 0.0)
# Out:
# Includes supplied:  ['z', 'theta']
# Reg Model:
# {'outcome': 't', 'model': ' 1 + covariate_name', 'params': ['t_Intercept', 't_covariate_name'], 'link_func': <function <lambda> at 0x14b2e05f0>}
# Uses Identity Link
# Reg Model:
# {'outcome': 'v', 'model': ' 1 + covariate_name', 'params': ['v_Intercept', 'v_covariate_name'], 'link_func': <function <lambda> at 0x145735560>}
# Uses Identity Link

# %%
hddmnn_reg.get_traces()
# Out:
#            a     a_std  a_subj.0  a_subj.1  a_subj.2   z_trans     z_std  \
# 0   1.477559  0.103175  1.459815  1.482286  1.363756  0.078777  0.180864
# 1   1.438756  0.077567  1.522642  1.520459  1.360386  0.240771  0.130108
# 2   1.441396  0.083723  1.568549  1.554878  1.455720  0.381962  0.332206
# 3   1.547785  0.072876  1.617294  1.572670  1.458502  0.360751  0.310657
# 4   1.509360  0.254181  1.586572  1.591300  1.493811  0.220284  0.176359
# ..       ...       ...       ...       ...       ...       ...       ...
# 95  1.445629  0.215615  1.736855  1.597348  1.531301  0.442348  0.100581
# 96  1.488850  0.215421  1.807176  1.712677  1.483871  0.479911  0.075626
# 97  1.696795  0.237240  1.960249  1.754559  1.474087  0.434548  0.128141
# 98  1.696011  0.284190  1.878722  1.671696  1.494241  0.347776  0.074791
# 99  1.944254  0.268486  1.875493  1.718800  1.575442  0.322078  0.097951
#
#     z_subj_trans.0  z_subj_trans.1  z_subj_trans.2  ...  t_Intercept_subj.0  \
# 0         0.202110        0.231831        0.103550  ...            1.367560
# 1         0.466823        0.261321        0.111159  ...            1.312911
# 2         0.884179        0.203548        0.078051  ...            1.294975
# 3         0.455676        0.131104        0.119158  ...            1.335891
# 4         0.314742        0.174716        0.213468  ...            1.366619
# ..             ...             ...             ...  ...                 ...
# 95        0.482330        0.336220        0.470043  ...            1.211402
# 96        0.480364        0.345936        0.462918  ...            1.227610
# 97        0.383530        0.253763        0.443550  ...            1.141630
# 98        0.405137        0.300665        0.273796  ...            1.217994
# 99        0.246855        0.307767        0.386597  ...            1.210445
#
#     t_Intercept_subj.1  t_Intercept_subj.2  t_covariate_name  v_Intercept  \
# 0             1.512285            1.228238          0.375510    -0.885565
# 1             1.516755            1.200974          0.377718    -0.954392
# 2             1.496273            1.158459          0.418771     1.455395
# 3             1.518916            1.166457          0.405225     0.412856
# 4             1.512876            1.161461          0.409221     0.456827
# ..                 ...                 ...               ...          ...
# 95            1.447429            1.143076          0.395899     0.617427
# 96            1.422774            1.134500          0.394237    -0.098373
# 97            1.419804            1.160456          0.421140     0.405362
# 98            1.427602            1.157876          0.429276     0.677832
# 99            1.434514            1.131663          0.409709     0.423816
#
#     v_Intercept_std  v_Intercept_subj.0  v_Intercept_subj.1  \
# 0          1.084926           -0.652055            1.315772
# 1          0.897032           -0.663959            1.351112
# 2          0.965197           -0.654141            1.372531
# 3          1.430772           -0.673684            1.723667
# 4          1.259092           -0.625328            1.710803
# ..              ...                 ...                 ...
# 95         1.204658           -0.743831            1.242257
# 96         1.478882           -0.603534            1.186999
# 97         0.856640           -0.663093            1.155590
# 98         0.893027           -0.534810            1.202651
# 99         1.424548           -0.611999            1.254561
#
#     v_Intercept_subj.2  v_covariate_name
# 0            -0.036244         -1.028078
# 1            -0.258059         -1.255857
# 2            -0.207525         -1.272315
# 3            -0.100438         -1.285578
# 4            -0.075845         -1.576364
# ..                 ...               ...
# 95           -0.361707         -1.134094
# 96           -0.558544         -1.052131
# 97           -0.583573         -1.107258
# 98           -0.626321         -1.102660
# 99           -0.596103         -1.036513
#
# [100 rows x 27 columns]

# %%
# Sample
hddmnn_reg.sample(nmcmc, burn = 100)
# Out:
# boundary violation of regressor part
# boundary violation of regressor part
# boundary violation of regressor part
#  [                  1%                  ] 2 of 200 complete in 0.6 secboundary violation of regressor part
# boundary violation of regressor part
#  [                  2%                  ] 4 of 200 complete in 1.3 secboundary violation of regressor part
# boundary violation of regressor part
#  [-                 3%                  ] 7 of 200 complete in 1.9 secboundary violation of regressor part
#  [-                 4%                  ] 9 of 200 complete in 2.4 secboundary violation of regressor part
#  [-----            13%                  ] 27 of 200 complete in 7.1 secboundary violation of regressor part
# boundary violation of regressor part
# boundary violation of regressor part
#  [-----            14%                  ] 29 of 200 complete in 7.6 secboundary violation of regressor part
# boundary violation of regressor part
# boundary violation of regressor part
#  [-----            15%                  ] 31 of 200 complete in 8.2 secboundary violation of regressor part
# boundary violation of regressor part
#  [-------          20%                  ] 41 of 200 complete in 10.8 secboundary violation of regressor part
#  [--------         22%                  ] 44 of 200 complete in 11.4 secboundary violation of regressor part
# boundary violation of regressor part
# boundary violation of regressor part
# boundary violation of regressor part
# boundary violation of regressor part
# boundary violation of regressor part
# boundary violation of regressor part
#  [--------         23%                  ] 47 of 200 complete in 12.1 secboundary violation of regressor part
# boundary violation of regressor part
# boundary violation of regressor part
#  [------------     32%                  ] 65 of 200 complete in 16.1 secboundary violation of regressor part
# boundary violation of regressor part
# boundary violation of regressor part
# boundary violation of regressor part
# boundary violation of regressor part
# boundary violation of regressor part
#  [------------     34%                  ] 68 of 200 complete in 16.8 secboundary violation of regressor part
# boundary violation of regressor part
#  [---------------  39%                  ] 79 of 200 complete in 19.4 secboundary violation of regressor part
#  [---------------  40%                  ] 81 of 200 complete in 19.9 secboundary violation of regressor part
# boundary violation of regressor part
# boundary violation of regressor part
# boundary violation of regressor part
# boundary violation of regressor part
# boundary violation of regressor part
# boundary violation of regressor part
#  [---------------  42%                  ] 84 of 200 complete in 20.6 secboundary violation of regressor part
#  [-----------------45%                  ] 90 of 200 complete in 22.0 secboundary violation of regressor part
#  [-----------------60%--                ] 120 of 200 complete in 28.7 secboundary violation of regressor part
#  [-----------------61%---               ] 123 of 200 complete in 29.4 secboundary violation of regressor part
# boundary violation of regressor part
#  [-----------------63%---               ] 126 of 200 complete in 30.2 secboundary violation of regressor part
# boundary violation of regressor part
# boundary violation of regressor part
# boundary violation of regressor part
# boundary violation of regressor part
# boundary violation of regressor part
# boundary violation of regressor part
# boundary violation of regressor part
# boundary violation of regressor part
# boundary violation of regressor part
#  [-----------------64%----              ] 129 of 200 complete in 30.8 secboundary violation of regressor part
# boundary violation of regressor part
# boundary violation of regressor part
# boundary violation of regressor part
# boundary violation of regressor part
#  [-----------------65%----              ] 131 of 200 complete in 31.4 secboundary violation of regressor part
#  [-----------------67%-----             ] 134 of 200 complete in 32.0 secboundary violation of regressor part
#  [-----------------68%------            ] 137 of 200 complete in 32.7 secboundary violation of regressor part
# boundary violation of regressor part
# boundary violation of regressor part
# boundary violation of regressor part
# boundary violation of regressor part
#  [-----------------70%------            ] 140 of 200 complete in 33.4 secboundary violation of regressor part
# boundary violation of regressor part
#  [-----------------73%-------           ] 146 of 200 complete in 34.8 secboundary violation of regressor part
# boundary violation of regressor part
#  [-----------------74%--------          ] 149 of 200 complete in 35.5 secboundary violation of regressor part
#  [-----------------92%---------------   ] 185 of 200 complete in 43.5 secboundary violation of regressor part
#  [-----------------94%---------------   ] 188 of 200 complete in 44.2 secboundary violation of regressor part
# boundary violation of regressor part
# boundary violation of regressor part
# boundary violation of regressor part
#  [-----------------100%-----------------] 200 of 200 complete in 47.3 sec

# %%
hddmnn_reg.nodes_db
# Out:
#                           knode_name stochastic observed   subj  \
# a                                  a       True    False  False
# a_std                          a_std       True    False  False
# a_tau                          a_tau      False    False  False
# a_subj.0                      a_subj       True    False   True
# a_subj.1                      a_subj       True    False   True
# a_subj.2                      a_subj       True    False   True
# z_trans                      z_trans       True    False  False
# z                                  z      False    False  False
# z_std                          z_std       True    False  False
# z_tau                          z_tau      False    False  False
# z_subj_trans.0          z_subj_trans       True    False   True
# z_subj_trans.1          z_subj_trans       True    False   True
# z_subj_trans.2          z_subj_trans       True    False   True
# z_subj.0                      z_subj      False    False   True
# z_subj.1                      z_subj      False    False   True
# z_subj.2                      z_subj      False    False   True
# theta                          theta       True    False  False
# theta_std                  theta_std       True    False  False
# theta_tau                  theta_tau      False    False  False
# theta_subj.0              theta_subj       True    False   True
# theta_subj.1              theta_subj       True    False   True
# theta_subj.2              theta_subj       True    False   True
# t_Intercept              t_Intercept       True    False  False
# t_Intercept_std      t_Intercept_std       True    False  False
# t_Intercept_tau      t_Intercept_tau      False    False  False
# t_Intercept_subj.0  t_Intercept_subj       True    False   True
# t_Intercept_subj.1  t_Intercept_subj       True    False   True
# t_Intercept_subj.2  t_Intercept_subj       True    False   True
# t_covariate_name    t_covariate_name       True    False  False
# t_reg.0                        t_reg      False    False   True
# t_reg.1                        t_reg      False    False   True
# t_reg.2                        t_reg      False    False   True
# v_Intercept              v_Intercept       True    False  False
# v_Intercept_std      v_Intercept_std       True    False  False
# v_Intercept_tau      v_Intercept_tau      False    False  False
# v_Intercept_subj.0  v_Intercept_subj       True    False   True
# v_Intercept_subj.1  v_Intercept_subj       True    False   True
# v_Intercept_subj.2  v_Intercept_subj       True    False   True
# v_covariate_name    v_covariate_name       True    False  False
# v_reg.0                        v_reg      False    False   True
# v_reg.1                        v_reg      False    False   True
# v_reg.2                        v_reg      False    False   True
# wfpt.0                          wfpt      False     True  False
# wfpt.1                          wfpt      False     True  False
# wfpt.2                          wfpt      False     True  False
#
#                                   node tag     depends hidden   rt response  \
# a                                    a  ()          []  False  NaN      NaN
# a_std                            a_std  ()          []  False  NaN      NaN
# a_tau                            a_tau  ()          []   True  NaN      NaN
# a_subj.0                      a_subj.0  ()  [subj_idx]  False  NaN      NaN
# a_subj.1                      a_subj.1  ()  [subj_idx]  False  NaN      NaN
# a_subj.2                      a_subj.2  ()  [subj_idx]  False  NaN      NaN
# z_trans                        z_trans  ()          []   True  NaN      NaN
# z                                    z  ()          []  False  NaN      NaN
# z_std                            z_std  ()          []  False  NaN      NaN
# z_tau                            z_tau  ()          []   True  NaN      NaN
# z_subj_trans.0          z_subj_trans.0  ()  [subj_idx]   True  NaN      NaN
# z_subj_trans.1          z_subj_trans.1  ()  [subj_idx]   True  NaN      NaN
# z_subj_trans.2          z_subj_trans.2  ()  [subj_idx]   True  NaN      NaN
# z_subj.0                      z_subj.0  ()  [subj_idx]  False  NaN      NaN
# z_subj.1                      z_subj.1  ()  [subj_idx]  False  NaN      NaN
# z_subj.2                      z_subj.2  ()  [subj_idx]  False  NaN      NaN
# theta                            theta  ()          []  False  NaN      NaN
# theta_std                    theta_std  ()          []  False  NaN      NaN
# theta_tau                    theta_tau  ()          []   True  NaN      NaN
# theta_subj.0              theta_subj.0  ()  [subj_idx]  False  NaN      NaN
# theta_subj.1              theta_subj.1  ()  [subj_idx]  False  NaN      NaN
# theta_subj.2              theta_subj.2  ()  [subj_idx]  False  NaN      NaN
# t_Intercept                t_Intercept  ()          []  False  NaN      NaN
# t_Intercept_std        t_Intercept_std  ()          []  False  NaN      NaN
# t_Intercept_tau        t_Intercept_tau  ()          []   True  NaN      NaN
# t_Intercept_subj.0  t_Intercept_subj.0  ()  [subj_idx]  False  NaN      NaN
# t_Intercept_subj.1  t_Intercept_subj.1  ()  [subj_idx]  False  NaN      NaN
# t_Intercept_subj.2  t_Intercept_subj.2  ()  [subj_idx]  False  NaN      NaN
# t_covariate_name      t_covariate_name  ()          []  False  NaN      NaN
# t_reg.0                        t_reg.0  ()  [subj_idx]   True  NaN      NaN
# t_reg.1                        t_reg.1  ()  [subj_idx]   True  NaN      NaN
# t_reg.2                        t_reg.2  ()  [subj_idx]   True  NaN      NaN
# v_Intercept                v_Intercept  ()          []  False  NaN      NaN
# v_Intercept_std        v_Intercept_std  ()          []  False  NaN      NaN
# v_Intercept_tau        v_Intercept_tau  ()          []   True  NaN      NaN
# v_Intercept_subj.0  v_Intercept_subj.0  ()  [subj_idx]  False  NaN      NaN
# v_Intercept_subj.1  v_Intercept_subj.1  ()  [subj_idx]  False  NaN      NaN
# v_Intercept_subj.2  v_Intercept_subj.2  ()  [subj_idx]  False  NaN      NaN
# v_covariate_name      v_covariate_name  ()          []  False  NaN      NaN
# v_reg.0                        v_reg.0  ()  [subj_idx]   True  NaN      NaN
# v_reg.1                        v_reg.1  ()  [subj_idx]   True  NaN      NaN
# v_reg.2                        v_reg.2  ()  [subj_idx]   True  NaN      NaN
# wfpt.0                          wfpt.0  ()  [subj_idx]  False  NaN      NaN
# wfpt.1                          wfpt.1  ()  [subj_idx]  False  NaN      NaN
# wfpt.2                          wfpt.2  ()  [subj_idx]  False  NaN      NaN
#
#                     ...    t theta       mean        std       2.5q  \
# a                   ...  NaN   NaN    1.58547   0.228664   0.992676
# a_std               ...  NaN   NaN   0.465806   0.260196  0.0612618
# a_tau               ...  NaN   NaN        NaN        NaN        NaN
# a_subj.0            ...  NaN   NaN    1.69446   0.208078    1.35551
# a_subj.1            ...  NaN   NaN     1.5808   0.188073    1.22869
# a_subj.2            ...  NaN   NaN    1.41715    0.10998    1.24566
# z_trans             ...  NaN   NaN        NaN        NaN        NaN
# z                   ...  NaN   NaN   0.558897  0.0313347   0.478572
# z_std               ...  NaN   NaN   0.142009   0.121952  0.0104632
# z_tau               ...  NaN   NaN        NaN        NaN        NaN
# z_subj_trans.0      ...  NaN   NaN        NaN        NaN        NaN
# z_subj_trans.1      ...  NaN   NaN        NaN        NaN        NaN
# z_subj_trans.2      ...  NaN   NaN        NaN        NaN        NaN
# z_subj.0            ...  NaN   NaN   0.567155  0.0234274   0.521696
# z_subj.1            ...  NaN   NaN   0.550113  0.0321152   0.461376
# z_subj.2            ...  NaN   NaN   0.554981  0.0318985    0.46352
# theta               ...  NaN   NaN   0.715427   0.366458 -0.0563938
# theta_std           ...  NaN   NaN   0.584429    0.25463   0.127035
# theta_tau           ...  NaN   NaN        NaN        NaN        NaN
# theta_subj.0        ...  NaN   NaN   0.515478  0.0859113   0.334999
# theta_subj.1        ...  NaN   NaN   0.905668  0.0594847   0.785458
# theta_subj.2        ...  NaN   NaN   0.799868  0.0519861   0.680603
# t_Intercept         ...  NaN   NaN    1.39812   0.257834   0.631239
# t_Intercept_std     ...  NaN   NaN   0.387213   0.256655  0.0954571
# t_Intercept_tau     ...  NaN   NaN        NaN        NaN        NaN
# t_Intercept_subj.0  ...  NaN   NaN    1.29315  0.0853287    1.13889
# t_Intercept_subj.1  ...  NaN   NaN    1.51947   0.043226     1.4276
# t_Intercept_subj.2  ...  NaN   NaN     1.2004   0.046876    1.12176
# t_covariate_name    ...  NaN   NaN   0.367896  0.0361089    0.28819
# t_reg.0             ...  NaN   NaN        NaN        NaN        NaN
# t_reg.1             ...  NaN   NaN        NaN        NaN        NaN
# t_reg.2             ...  NaN   NaN        NaN        NaN        NaN
# v_Intercept         ...  NaN   NaN  0.0812004   0.594603  -0.961972
# v_Intercept_std     ...  NaN   NaN    1.02621   0.241122   0.613254
# v_Intercept_tau     ...  NaN   NaN        NaN        NaN        NaN
# v_Intercept_subj.0  ...  NaN   NaN  -0.646725   0.155094   -1.01315
# v_Intercept_subj.1  ...  NaN   NaN    1.27748   0.244101   0.813123
# v_Intercept_subj.2  ...  NaN   NaN  -0.411265   0.267714  -0.871026
# v_covariate_name    ...  NaN   NaN   -1.19497   0.278983   -1.84027
# v_reg.0             ...  NaN   NaN        NaN        NaN        NaN
# v_reg.1             ...  NaN   NaN        NaN        NaN        NaN
# v_reg.2             ...  NaN   NaN        NaN        NaN        NaN
# wfpt.0              ...  NaN   NaN        NaN        NaN        NaN
# wfpt.1              ...  NaN   NaN        NaN        NaN        NaN
# wfpt.2              ...  NaN   NaN        NaN        NaN        NaN
#
#                           25q       50q       75q     97.5q      mc err
# a                     1.46941     1.599   1.70354   1.97151   0.0228664
# a_std                0.269731   0.37411  0.687854  0.965581   0.0260196
# a_tau                     NaN       NaN       NaN       NaN         NaN
# a_subj.0              1.51952   1.70751   1.90702   1.99493   0.0208078
# a_subj.1              1.41765   1.58561    1.7188   1.89595   0.0188073
# a_subj.2              1.32771   1.41178   1.49424    1.6219    0.010998
# z_trans                   NaN       NaN       NaN       NaN         NaN
# z                    0.547898  0.562075  0.577731   0.61065  0.00313347
# z_std               0.0396336  0.111738  0.210647  0.452617   0.0121952
# z_tau                     NaN       NaN       NaN       NaN         NaN
# z_subj_trans.0            NaN       NaN       NaN       NaN         NaN
# z_subj_trans.1            NaN       NaN       NaN       NaN         NaN
# z_subj_trans.2            NaN       NaN       NaN       NaN         NaN
# z_subj.0             0.553625  0.564755  0.585921  0.607763  0.00234274
# z_subj.1              0.53462  0.559428  0.569009  0.592647  0.00321152
# z_subj.2             0.542722  0.558338  0.576428  0.605276  0.00318985
# theta                0.524343  0.742069    1.0263   1.37709   0.0366458
# theta_std            0.369767  0.616384  0.816648  0.968727    0.025463
# theta_tau                 NaN       NaN       NaN       NaN         NaN
# theta_subj.0          0.44843  0.527685  0.592988  0.636971  0.00859113
# theta_subj.1         0.869085  0.908086  0.954762   1.00193  0.00594847
# theta_subj.2          0.77418  0.806093  0.837991  0.887123  0.00519861
# t_Intercept           1.27993    1.3764   1.52298   1.92225   0.0257834
# t_Intercept_std      0.203384  0.301413  0.550405   0.95306   0.0256655
# t_Intercept_tau           NaN       NaN       NaN       NaN         NaN
# t_Intercept_subj.0    1.22761   1.29748    1.3567   1.43415  0.00853287
# t_Intercept_subj.1    1.49322   1.51575   1.54756   1.59518   0.0043226
# t_Intercept_subj.2    1.15846   1.19658   1.24468   1.28026   0.0046876
# t_covariate_name     0.346626  0.376638  0.394965  0.423875  0.00361089
# t_reg.0                   NaN       NaN       NaN       NaN         NaN
# t_reg.1                   NaN       NaN       NaN       NaN         NaN
# t_reg.2                   NaN       NaN       NaN       NaN         NaN
# v_Intercept         -0.324337  0.120701  0.481456     1.273   0.0594603
# v_Intercept_std      0.854109   1.03024   1.20466   1.44971   0.0241122
# v_Intercept_tau           NaN       NaN       NaN       NaN         NaN
# v_Intercept_subj.0  -0.728173 -0.654141 -0.540535 -0.378154   0.0155094
# v_Intercept_subj.1    1.13639   1.25456   1.40669   1.89048   0.0244101
# v_Intercept_subj.2  -0.610798  -0.44261 -0.251457  0.178432   0.0267714
# v_covariate_name     -1.34935  -1.17053  -1.02808 -0.666737   0.0278983
# v_reg.0                   NaN       NaN       NaN       NaN         NaN
# v_reg.1                   NaN       NaN       NaN       NaN         NaN
# v_reg.2                   NaN       NaN       NaN       NaN         NaN
# wfpt.0                    NaN       NaN       NaN       NaN         NaN
# wfpt.1                    NaN       NaN       NaN       NaN         NaN
# wfpt.2                    NaN       NaN       NaN       NaN         NaN
#
# [45 rows x 25 columns]

# %% [markdown]
# # Testing Graph

# %%
# Metadata
nmcmc = 2000
burn = 50
model = 'angle'
n_trials_per_subject = 300
n_subjects = 10

# %%
# test regressors only False
# add p_outliers to the generator !
data, full_parameter_dict = hddm.simulators.hddm_dataset_generators.simulator_h_c(data = None, 
                                                                                  n_subjects = n_subjects,
                                                                                  n_trials_per_subject = n_trials_per_subject,
                                                                                  model = model,
                                                                                  p_outlier = 0.00,
                                                                                  conditions = None, 
                                                                                  depends_on = None, 
                                                                                  regression_models = None,
                                                                                  regression_covariates = None,
                                                                                  group_only_regressors = False,
                                                                                  group_only = None,
                                                                                  fixed_at_default = None)

# %%
hddmnn_model = hddm.HDDMnn(data,
                               model = model,
                               informative = False,
                               include = hddm.simulators.model_config[model]['hddm_include'], #is_group_model = True,
                               p_outlier = 0.05)
# Out:
# Includes supplied:  ['z', 'theta']

# %%
hddmnn_model.sample(nmcmc, burn = burn)
# Out:
#  [-----------------100%-----------------] 2001 of 2000 complete in 572.3 sec

# %%
from kabuki.analyze import _parents_to_random_posterior_sample
#import ipdb
# def data_processor(x = None):
#     #print(x[:, 0] * x[:, 1])
#     return x[:, 0] * x[:, 1]

plot_posterior_predictive(model = hddmnn_model, plot_func = _plot_posterior_pdf_node_nn,  
                          value_range = np.arange(-5, 5, 0.01), samples = 50,
                          **{'bin_size': 0.05,
                             'plot_likelihood_raw': True,
                             'add_posterior_mean': True,
                             'alpha': 0.05,
                             'plot_type': 'step',
                             'linewidth': 2},
                           figsize = (12, 4))
