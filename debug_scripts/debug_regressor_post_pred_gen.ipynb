# %%
# %load_ext autoreload

# %%
# !pwd
# Out:
# /Users/afengler/OneDrive/git_repos/hddmnn_tutorial

# %%
# %reload_ext autoreload

# MODULE IMPORTS ----
# warning settings
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# Data management
import pandas as pd
import numpy as np
import pickle

# Plotting
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns

# Stats functionality
from statsmodels.distributions.empirical_distribution import ECDF

# HDDM
import hddm

import pymc as pm
import os

# %%
def _post_pred_generate(bottom_node, samples=500, data=None, append_data=False, add_model_parameters=False):
    """Generate posterior predictive data from a single observed node."""
    datasets = []

    ##############################
    # Sample and generate stats
    for sample in range(samples):
        _parents_to_random_posterior_sample(bottom_node)
        # Generate data from bottom node
        sampled_data = bottom_node.random(add_model_parameters = add_model_parameters)
        if append_data and data is not None:
            sampled_data = sampled_data.join(data.reset_index(), lsuffix='_sampled')
        datasets.append(sampled_data)
    return datasets

# %%
def _parents_to_random_posterior_sample(bottom_node, pos=None):
    """Walks through parents and sets them to pos sample."""
    for i, parent in enumerate(bottom_node.extended_parents):
        if not isinstance(parent, pm.Node): # Skip non-stochastic nodes
            continue

        if pos is None:
            # Set to random posterior position
            pos = np.random.randint(0, len(parent.trace()))

        assert len(parent.trace()) >= pos, "pos larger than posterior sample size"
        parent.value = parent.trace()[pos]

# %%
def pretty_tag(tag):
    return tag[0] if len(tag) == 1 else ', '.join(str(tag))

# %% [markdown]
# # Testing Fun

# %%
# Metadata
nmcmc = 200
model = 'angle'
n_samples_by_subject = 500

# %%
data, full_parameter_dict = hddm.simulators.hddm_dataset_generators.simulator_h_c(n_subjects = 3,
                                                                                  n_samples_by_subject = n_samples_by_subject,
                                                                                  model = model,
                                                                                  p_outlier = 0.00,
                                                                                  conditions = None, 
                                                                                  depends_on = None, 
                                                                                  regression_models = ['t ~ 1 + covariate_name', 'v ~ 1 + covariate_name'], 
                                                                                  regression_covariates = {'covariate_name': {'type': 'continuous', 'range': (0, 1)},
                                                                                                          'covariate_name_2': {'type': 'continuous', 'range': (0, 1)}},
                                                                                  group_only_regressors = False,
                                                                                  group_only = None,
                                                                                  fixed_at_default = None)

# %%
# Set up the regressor a regressor:
reg_model_v = {'model': 'v ~ 1 + covariate_name + covariate_name_2', 'link_func': lambda x: x}
reg_model_t = {'model': 't ~ 1 + covariate_name', 'link_func': lambda x: x}
reg_descr = [reg_model_t, reg_model_v]

# %%
# Make HDDM model
hddmnn_reg = hddm.HDDMnnRegressor(data,
                                  reg_descr, 
                                  include = hddm.simulators.model_config[model]['hddm_include'],
                                  model = model,
                                  informative = False,
                                  p_outlier = 0.0)
# Out:
# Includes supplied:  ['z', 'theta']
# Reg Model:
# {'outcome': 't', 'model': ' 1 + covariate_name', 'params': ['t_Intercept', 't_covariate_name'], 'link_func': <function <lambda> at 0x10e950b00>}
# Uses Identity Link
# Reg Model:
# {'outcome': 'v', 'model': ' 1 + covariate_name + covariate_name_2', 'params': ['v_Intercept', 'v_covariate_name', 'v_covariate_name_2'], 'link_func': <function <lambda> at 0x10e950320>}
# Uses Identity Link

# %%
hddmnn_reg.get_traces()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-df5ede1ccd2e> in <module>
# ----> 1 hddmnn_reg.get_traces()
#
# ~/OneDrive/project_hddm_extension/kabuki/kabuki/hierarchical.py in get_traces(self)
#     938         calling model.get_traces().to_csv('samples.csv')
#     939         """
# --> 940         return pd.DataFrame({i.__name__: i.trace() for i in self.get_stochastics().node})
#     941
#     942     def get_data_nodes(self, idx):
#
# ~/OneDrive/project_hddm_extension/kabuki/kabuki/hierarchical.py in <dictcomp>(.0)
#     938         calling model.get_traces().to_csv('samples.csv')
#     939         """
# --> 940         return pd.DataFrame({i.__name__: i.trace() for i in self.get_stochastics().node})
#     941
#     942     def get_data_nodes(self, idx):
#
# AttributeError: 'Uniform' object has no attribute 'trace'

# %%
# Sample
hddmnn_reg.sample(nmcmc, burn = 100)
# Out:
# boundary violation of regressor part
#  [-----------------100%-----------------] 200 of 200 complete in 82.3 sec

# %%
hddmnn_reg.nodes_db
# Out:
#                             knode_name stochastic observed   subj  \
# a                                    a       True    False  False
# a_std                            a_std       True    False  False
# a_tau                            a_tau      False    False  False
# a_subj.0                        a_subj       True    False   True
# a_subj.1                        a_subj       True    False   True
# a_subj.2                        a_subj       True    False   True
# z_trans                        z_trans       True    False  False
# z                                    z      False    False  False
# z_std                            z_std       True    False  False
# z_tau                            z_tau      False    False  False
# z_subj_trans.0            z_subj_trans       True    False   True
# z_subj_trans.1            z_subj_trans       True    False   True
# z_subj_trans.2            z_subj_trans       True    False   True
# z_subj.0                        z_subj      False    False   True
# z_subj.1                        z_subj      False    False   True
# z_subj.2                        z_subj      False    False   True
# theta                            theta       True    False  False
# theta_std                    theta_std       True    False  False
# theta_tau                    theta_tau      False    False  False
# theta_subj.0                theta_subj       True    False   True
# theta_subj.1                theta_subj       True    False   True
# theta_subj.2                theta_subj       True    False   True
# t_Intercept                t_Intercept       True    False  False
# t_Intercept_std        t_Intercept_std       True    False  False
# t_Intercept_tau        t_Intercept_tau      False    False  False
# t_Intercept_subj.0    t_Intercept_subj       True    False   True
# t_Intercept_subj.1    t_Intercept_subj       True    False   True
# t_Intercept_subj.2    t_Intercept_subj       True    False   True
# t_covariate_name      t_covariate_name       True    False  False
# t_reg.0                          t_reg      False    False   True
# t_reg.1                          t_reg      False    False   True
# t_reg.2                          t_reg      False    False   True
# v_Intercept                v_Intercept       True    False  False
# v_Intercept_std        v_Intercept_std       True    False  False
# v_Intercept_tau        v_Intercept_tau      False    False  False
# v_Intercept_subj.0    v_Intercept_subj       True    False   True
# v_Intercept_subj.1    v_Intercept_subj       True    False   True
# v_Intercept_subj.2    v_Intercept_subj       True    False   True
# v_covariate_name      v_covariate_name       True    False  False
# v_covariate_name_2  v_covariate_name_2       True    False  False
# v_reg.0                          v_reg      False    False   True
# v_reg.1                          v_reg      False    False   True
# v_reg.2                          v_reg      False    False   True
# wfpt.0                            wfpt      False     True  False
# wfpt.1                            wfpt      False     True  False
# wfpt.2                            wfpt      False     True  False
#
#                                   node tag     depends hidden   rt response  \
# a                                    a  ()          []  False  NaN      NaN
# a_std                            a_std  ()          []  False  NaN      NaN
# a_tau                            a_tau  ()          []   True  NaN      NaN
# a_subj.0                      a_subj.0  ()  [subj_idx]  False  NaN      NaN
# a_subj.1                      a_subj.1  ()  [subj_idx]  False  NaN      NaN
# a_subj.2                      a_subj.2  ()  [subj_idx]  False  NaN      NaN
# z_trans                        z_trans  ()          []   True  NaN      NaN
# z                                    z  ()          []  False  NaN      NaN
# z_std                            z_std  ()          []  False  NaN      NaN
# z_tau                            z_tau  ()          []   True  NaN      NaN
# z_subj_trans.0          z_subj_trans.0  ()  [subj_idx]   True  NaN      NaN
# z_subj_trans.1          z_subj_trans.1  ()  [subj_idx]   True  NaN      NaN
# z_subj_trans.2          z_subj_trans.2  ()  [subj_idx]   True  NaN      NaN
# z_subj.0                      z_subj.0  ()  [subj_idx]  False  NaN      NaN
# z_subj.1                      z_subj.1  ()  [subj_idx]  False  NaN      NaN
# z_subj.2                      z_subj.2  ()  [subj_idx]  False  NaN      NaN
# theta                            theta  ()          []  False  NaN      NaN
# theta_std                    theta_std  ()          []  False  NaN      NaN
# theta_tau                    theta_tau  ()          []   True  NaN      NaN
# theta_subj.0              theta_subj.0  ()  [subj_idx]  False  NaN      NaN
# theta_subj.1              theta_subj.1  ()  [subj_idx]  False  NaN      NaN
# theta_subj.2              theta_subj.2  ()  [subj_idx]  False  NaN      NaN
# t_Intercept                t_Intercept  ()          []  False  NaN      NaN
# t_Intercept_std        t_Intercept_std  ()          []  False  NaN      NaN
# t_Intercept_tau        t_Intercept_tau  ()          []   True  NaN      NaN
# t_Intercept_subj.0  t_Intercept_subj.0  ()  [subj_idx]  False  NaN      NaN
# t_Intercept_subj.1  t_Intercept_subj.1  ()  [subj_idx]  False  NaN      NaN
# t_Intercept_subj.2  t_Intercept_subj.2  ()  [subj_idx]  False  NaN      NaN
# t_covariate_name      t_covariate_name  ()          []  False  NaN      NaN
# t_reg.0                        t_reg.0  ()  [subj_idx]   True  NaN      NaN
# t_reg.1                        t_reg.1  ()  [subj_idx]   True  NaN      NaN
# t_reg.2                        t_reg.2  ()  [subj_idx]   True  NaN      NaN
# v_Intercept                v_Intercept  ()          []  False  NaN      NaN
# v_Intercept_std        v_Intercept_std  ()          []  False  NaN      NaN
# v_Intercept_tau        v_Intercept_tau  ()          []   True  NaN      NaN
# v_Intercept_subj.0  v_Intercept_subj.0  ()  [subj_idx]  False  NaN      NaN
# v_Intercept_subj.1  v_Intercept_subj.1  ()  [subj_idx]  False  NaN      NaN
# v_Intercept_subj.2  v_Intercept_subj.2  ()  [subj_idx]  False  NaN      NaN
# v_covariate_name      v_covariate_name  ()          []  False  NaN      NaN
# v_covariate_name_2  v_covariate_name_2  ()          []  False  NaN      NaN
# v_reg.0                        v_reg.0  ()  [subj_idx]   True  NaN      NaN
# v_reg.1                        v_reg.1  ()  [subj_idx]   True  NaN      NaN
# v_reg.2                        v_reg.2  ()  [subj_idx]   True  NaN      NaN
# wfpt.0                          wfpt.0  ()  [subj_idx]  False  NaN      NaN
# wfpt.1                          wfpt.1  ()  [subj_idx]  False  NaN      NaN
# wfpt.2                          wfpt.2  ()  [subj_idx]  False  NaN      NaN
#
#                     ...    t theta      mean        std       2.5q        25q  \
# a                   ...  NaN   NaN   1.29505   0.363837   0.446245    1.10328
# a_std               ...  NaN   NaN  0.494237    0.27999   0.106587   0.197931
# a_tau               ...  NaN   NaN       NaN        NaN        NaN        NaN
# a_subj.0            ...  NaN   NaN   1.28247  0.0890284    1.14514    1.20805
# a_subj.1            ...  NaN   NaN   1.30242   0.168967     1.0358    1.23106
# a_subj.2            ...  NaN   NaN   1.45676  0.0871514     1.3075     1.3897
# z_trans             ...  NaN   NaN       NaN        NaN        NaN        NaN
# z                   ...  NaN   NaN  0.529456  0.0251117   0.464475    0.51664
# z_std               ...  NaN   NaN  0.186497   0.149012  0.0288312  0.0782578
# z_tau               ...  NaN   NaN       NaN        NaN        NaN        NaN
# z_subj_trans.0      ...  NaN   NaN       NaN        NaN        NaN        NaN
# z_subj_trans.1      ...  NaN   NaN       NaN        NaN        NaN        NaN
# z_subj_trans.2      ...  NaN   NaN       NaN        NaN        NaN        NaN
# z_subj.0            ...  NaN   NaN  0.531494  0.0243131   0.481196    0.51465
# z_subj.1            ...  NaN   NaN  0.528265  0.0242898   0.479074   0.515261
# z_subj.2            ...  NaN   NaN  0.532894  0.0208732    0.49043   0.520578
# theta               ...  NaN   NaN  0.978674   0.119974   0.802552    0.92585
# theta_std           ...  NaN   NaN  0.185966   0.225922  0.0279965  0.0585976
# theta_tau           ...  NaN   NaN       NaN        NaN        NaN        NaN
# theta_subj.0        ...  NaN   NaN  0.969245  0.0380214   0.902267   0.941166
# theta_subj.1        ...  NaN   NaN   1.00074  0.0515325   0.894195   0.979161
# theta_subj.2        ...  NaN   NaN  0.884097  0.0352473   0.817821   0.856406
# t_Intercept         ...  NaN   NaN   1.12414   0.223849   0.537037    1.06933
# t_Intercept_std     ...  NaN   NaN  0.273025   0.288966  0.0230167  0.0725486
# t_Intercept_tau     ...  NaN   NaN       NaN        NaN        NaN        NaN
# t_Intercept_subj.0  ...  NaN   NaN   1.08678  0.0274974    1.02747    1.07096
# t_Intercept_subj.1  ...  NaN   NaN   1.11034  0.0508212   0.984114    1.07677
# t_Intercept_subj.2  ...  NaN   NaN   1.15103  0.0352433    1.09299    1.12519
# t_covariate_name    ...  NaN   NaN -0.170207  0.0275557  -0.221579  -0.188839
# t_reg.0             ...  NaN   NaN       NaN        NaN        NaN        NaN
# t_reg.1             ...  NaN   NaN       NaN        NaN        NaN        NaN
# t_reg.2             ...  NaN   NaN       NaN        NaN        NaN        NaN
# v_Intercept         ...  NaN   NaN -0.356027   0.377194   -1.02632  -0.552149
# v_Intercept_std     ...  NaN   NaN  0.330027   0.286262  0.0325579   0.126754
# v_Intercept_tau     ...  NaN   NaN       NaN        NaN        NaN        NaN
# v_Intercept_subj.0  ...  NaN   NaN -0.239529   0.301107  -0.639813  -0.448807
# v_Intercept_subj.1  ...  NaN   NaN -0.401692   0.379848   -1.25061  -0.589355
# v_Intercept_subj.2  ...  NaN   NaN -0.376597   0.301115  -0.849824  -0.587936
# v_covariate_name    ...  NaN   NaN -0.223469   0.349566  -0.863126  -0.432581
# v_covariate_name_2  ...  NaN   NaN  0.361585   0.300219  -0.249795   0.148573
# v_reg.0             ...  NaN   NaN       NaN        NaN        NaN        NaN
# v_reg.1             ...  NaN   NaN       NaN        NaN        NaN        NaN
# v_reg.2             ...  NaN   NaN       NaN        NaN        NaN        NaN
# wfpt.0              ...  NaN   NaN       NaN        NaN        NaN        NaN
# wfpt.1              ...  NaN   NaN       NaN        NaN        NaN        NaN
# wfpt.2              ...  NaN   NaN       NaN        NaN        NaN        NaN
#
#                           50q        75q     97.5q      mc err
# a                     1.31346    1.56026   1.98659   0.0363837
# a_std                0.532621   0.729738  0.996017    0.027999
# a_tau                     NaN        NaN       NaN         NaN
# a_subj.0              1.27032    1.36239    1.4749  0.00890284
# a_subj.1              1.31231    1.36233      1.81   0.0168967
# a_subj.2              1.46468     1.5224    1.6144  0.00871514
# z_trans                   NaN        NaN       NaN         NaN
# z                    0.531172   0.545438  0.572964  0.00251117
# z_std                0.124846    0.29077  0.567063   0.0149012
# z_tau                     NaN        NaN       NaN         NaN
# z_subj_trans.0            NaN        NaN       NaN         NaN
# z_subj_trans.1            NaN        NaN       NaN         NaN
# z_subj_trans.2            NaN        NaN       NaN         NaN
# z_subj.0             0.531187   0.546418  0.589748  0.00243131
# z_subj.1             0.527074   0.544627  0.569507  0.00242898
# z_subj.2             0.532445   0.545402  0.573636  0.00208732
# theta                0.959324    1.00184   1.36215   0.0119974
# theta_std           0.0957595   0.190491  0.929777   0.0225922
# theta_tau                 NaN        NaN       NaN         NaN
# theta_subj.0         0.968847     1.0007   1.04143  0.00380214
# theta_subj.1          1.00757    1.02635   1.09935  0.00515325
# theta_subj.2         0.888231   0.911332  0.958564  0.00352473
# t_Intercept           1.11749    1.20253   1.70344   0.0223849
# t_Intercept_std        0.1226   0.460597  0.947629   0.0288966
# t_Intercept_tau           NaN        NaN       NaN         NaN
# t_Intercept_subj.0    1.09336    1.10606   1.13206  0.00274974
# t_Intercept_subj.1    1.11468    1.15121    1.1933  0.00508212
# t_Intercept_subj.2    1.14398    1.16991   1.23075  0.00352433
# t_covariate_name    -0.171358   -0.15397 -0.110932  0.00275557
# t_reg.0                   NaN        NaN       NaN         NaN
# t_reg.1                   NaN        NaN       NaN         NaN
# t_reg.2                   NaN        NaN       NaN         NaN
# v_Intercept         -0.428259  -0.114629  0.397397   0.0377194
# v_Intercept_std      0.252415    0.49013   1.12841   0.0286262
# v_Intercept_tau           NaN        NaN       NaN         NaN
# v_Intercept_subj.0  -0.321516  0.0742693  0.410248   0.0301107
# v_Intercept_subj.1  -0.439305  -0.100348  0.258208   0.0379848
# v_Intercept_subj.2  -0.425066  -0.132759  0.244428   0.0301115
# v_covariate_name    -0.169134 -0.0318032  0.512253   0.0349566
# v_covariate_name_2   0.380985   0.567825  0.924363   0.0300219
# v_reg.0                   NaN        NaN       NaN         NaN
# v_reg.1                   NaN        NaN       NaN         NaN
# v_reg.2                   NaN        NaN       NaN         NaN
# wfpt.0                    NaN        NaN       NaN         NaN
# wfpt.1                    NaN        NaN       NaN         NaN
# wfpt.2                    NaN        NaN       NaN         NaN
#
# [46 rows x 26 columns]

# %%
from kabuki.analyze import post_pred_gen

# %%
post_pred_gen(hddmnn_reg, groupby = ['subj_idx'])
# Out:
#  [-----------------------133%-----------------------] 4 of 3 complete in 6.9 sec
#                         rt  response  model
# node   sample
# wfpt.0 0      0   1.230755        -1  angle
#               1   1.118580         1  angle
#               2   1.403114         1  angle
#               3   1.546864         1  angle
#               4   1.162932         1  angle
# ...                    ...       ...    ...
# wfpt.2 499    95  1.221503        -1  angle
#               96  1.875936         1  angle
#               97  1.546930        -1  angle
#               98  1.440528        -1  angle
#               99  1.829517        -1  angle
#
# [150000 rows x 3 columns]

# %% [markdown]
# # Testing Graph

# %%
# Metadata
nmcmc = 2000
burn = 50
model = 'angle'
n_trials_per_subject = 300
n_subjects = 10

# %%
# test regressors only False
# add p_outliers to the generator !
data, full_parameter_dict = hddm.simulators.hddm_dataset_generators.simulator_h_c(data = None, 
                                                                                  n_subjects = n_subjects,
                                                                                  n_trials_per_subject = n_trials_per_subject,
                                                                                  model = model,
                                                                                  p_outlier = 0.00,
                                                                                  conditions = None, 
                                                                                  depends_on = None, 
                                                                                  regression_models = None,
                                                                                  regression_covariates = None,
                                                                                  group_only_regressors = False,
                                                                                  group_only = None,
                                                                                  fixed_at_default = None)

# %%
hddmnn_model = hddm.HDDMnn(data,
                               model = model,
                               informative = False,
                               include = hddm.simulators.model_config[model]['hddm_include'], #is_group_model = True,
                               p_outlier = 0.05)
# Out:
# Includes supplied:  ['z', 'theta']

# %%
hddmnn_model.sample(nmcmc, burn = burn)
# Out:
#  [-----------------100%-----------------] 2001 of 2000 complete in 572.3 sec

# %%
from kabuki.analyze import _parents_to_random_posterior_sample
#import ipdb
# def data_processor(x = None):
#     #print(x[:, 0] * x[:, 1])
#     return x[:, 0] * x[:, 1]

plot_posterior_predictive(model = hddmnn_model, plot_func = _plot_posterior_pdf_node_nn,  
                          value_range = np.arange(-5, 5, 0.01), samples = 50,
                          **{'bin_size': 0.05,
                             'plot_likelihood_raw': True,
                             'add_posterior_mean': True,
                             'alpha': 0.05,
                             'plot_type': 'step',
                             'linewidth': 2},
                           figsize = (12, 4))
